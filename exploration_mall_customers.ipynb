# %% [markdown]
# ## Exploration: Mall Customers - Regression Module

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pydataset
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer
from sklearn.model_selection import train_test_split

from env import get_db_url
import os
import warnings
warnings.filterwarnings('ignore')

from explore import split_data
from explore import plot_variable_pairs
from explore import plot_categorical_and_continuous_vars

# %%
query = '''SELECT * FROM customers'''
df = pd.read_sql(query, get_db_url('mall_customers'))
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
train_val, test = train_test_split(df, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((112, 5), (48, 5), (40, 5))

# %%
columns = train[['age', 'annual_income', 'spending_score']]
plot_variable_pairs(columns)

# %%
plot_categorical_and_continuous_vars(train, 'gender', 'spending_score')
