# %% [markdown]
# ## Feature Engineering Exercises - Regression Module

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from pydataset import data

import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, RFE, f_regression, SequentialFeatureSelector
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer

from feature_engineering import select_k_best
from feature_engineering import rfe

# %%
#pull the dataset from pydataset
df = data('tips')
#view the first 5 rows
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#create a price per person column by dividing the total bill column by the party size column
df['price_per_person'] = df.total_bill / df['size']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 1       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 2       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 3       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 4       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 5       24.59  3.61  Female     No  Sun  Dinner     4          6.147500

# %%
#assign all the 'object' type columns to a variable to encode
encode_cols = [col for col in df.columns if df[col].dtype == 'O']
#loop through the object type columns and encode with dummie variables   
for col in encode_cols:
    dummie_df = pd.get_dummies(df[col], prefix = df[col].name, drop_first = True)
    df = pd.concat([df, dummie_df], axis=1)

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 1       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 2       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 3       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 4       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 5       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#    sex_Male  smoker_Yes  day_Sat  day_Sun  day_Thur  time_Lunch
# 1         0           0        0        1         0           0
# 2         1           0        0        1         0           0
# 3         1           0        0        1         0           0
# 4         1           0        0        1         0           0
# 5         0           0        0        1         0           0

# %%
#look at the data types for the df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 1 to 244
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   sex_Male          244 non-null    uint8
#  9   smoker_Yes        244 non-null    uint8
#  10  day_Sat           244 non-null    uint8
#  11  day_Sun           244 non-null    uint8
#  12  day_Thur          244 non-null    uint8
#  13  time_Lunch        244 non-null    uint8
# dtypes: float64(3), int64(1), object(4), uint8(6)
# memory usage: 18.6+ KB

# %%
#drop the original columns from the ones that were encoded
df = df.drop(columns=encode_cols)
df.head()
# Out:
#    total_bill   tip  size  price_per_person  sex_Male  smoker_Yes  day_Sat  \
# 1       16.99  1.01     2          8.495000         0           0        0
# 2       10.34  1.66     3          3.446667         1           0        0
# 3       21.01  3.50     3          7.003333         1           0        0
# 4       23.68  3.31     2         11.840000         1           0        0
# 5       24.59  3.61     4          6.147500         0           0        0
#
#    day_Sun  day_Thur  time_Lunch
# 1        1         0           0
# 2        1         0           0
# 3        1         0           0
# 4        1         0           0
# 5        1         0           0

# %%
#split the data into train, validate, test
train_val, test = train_test_split(df, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((136, 10), (59, 10), (49, 10))

# %%
#verify no object data types are left
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 19 to 167
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        136 non-null    float64
#  1   tip               136 non-null    float64
#  2   size              136 non-null    int64
#  3   price_per_person  136 non-null    float64
#  4   sex_Male          136 non-null    uint8
#  5   smoker_Yes        136 non-null    uint8
#  6   day_Sat           136 non-null    uint8
#  7   day_Sun           136 non-null    uint8
#  8   day_Thur          136 non-null    uint8
#  9   time_Lunch        136 non-null    uint8
# dtypes: float64(3), int64(1), uint8(6)
# memory usage: 6.1 KB

# %%
#assign the x and y variables from the train dataset
x_train = train.drop(columns='tip')
y_train = train[['tip']]
x_train.head()
# Out:
#      total_bill  size  price_per_person  sex_Male  smoker_Yes  day_Sat  \
# 19        16.97     3          5.656667         0           0        0
# 173        7.25     2          3.625000         1           1        0
# 119       12.43     2          6.215000         0           0        0
# 29        21.70     2         10.850000         1           0        1
# 238       32.83     2         16.415000         1           1        1
#
#      day_Sun  day_Thur  time_Lunch
# 19         1         0           0
# 173        1         0           0
# 119        0         1           1
# 29         0         0           0
# 238        0         0           0

# %%
y_train.head()
# Out:
#       tip
# 19   3.50
# 173  5.15
# 119  1.80
# 29   4.30
# 238  1.17

# %%
#create the K Best object
kbest = SelectKBest(f_regression, k=2)
#fit the K Best object with the train data
kbest.fit(x_train, y_train)
# Out:
# SelectKBest(k=2, score_func=<function f_regression at 0x7f8d5c9d08b0>)

# %%
#output the results from the K Best 
kbest_results = pd.DataFrame(dict(p=kbest.pvalues_, f=kbest.scores_), index=x_train.columns)
kbest_results
# Out:
#                              p           f
# total_bill        7.186470e-20  115.984909
# size              1.341642e-12   61.259089
# price_per_person  1.310327e-03   10.777792
# sex_Male          2.844794e-01    1.154792
# smoker_Yes        5.579978e-01    0.344909
# day_Sat           9.550468e-01    0.003190
# day_Sun           1.236625e-01    2.400404
# day_Thur          3.013774e-01    1.076380
# time_Lunch        1.821449e-01    1.798647

# %%
x_train.columns[kbest.get_support()]
# Out:
# Index(['total_bill', 'size'], dtype='object')

# %%
list(x_train.columns[kbest.get_support()])
# Out:
# ['total_bill', 'size']

# %%
#create a model object
model = LinearRegression()
#create an rfe object and assign it the model object
rfe = RFE(model, n_features_to_select=2)
#train/fit the rfe object
rfe.fit(x_train, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=2)

# %%
#output the results 
pd.DataFrame({'rfe_ranking': rfe.ranking_}, index=x_train.columns)
# Out:
#                   rfe_ranking
# total_bill                  5
# size                        1
# price_per_person            3
# sex_Male                    2
# smoker_Yes                  7
# day_Sat                     4
# day_Sun                     6
# day_Thur                    1
# time_Lunch                  8

# %%
x_train.columns[rfe.get_support()]
# Out:
# Index(['size', 'day_Thur'], dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# #### Add a Scaler to the above dataset/process
# - Reset the Kernel
#
# - Run the imports
#
# - Then run top down from here

# %%
#pull the tips dataset from pydataset
df = data('tips')
#view the df
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#create the proce per person column
df['price_per_person'] = df.total_bill / df['size']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 1       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 2       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 3       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 4       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 5       24.59  3.61  Female     No  Sun  Dinner     4          6.147500

# %%
#select the columns to encode
encode_cols = [col for col in df.columns if df[col].dtype == 'O']
#encode the columns   
for col in encode_cols:
    dummie_df = pd.get_dummies(df[col], prefix = df[col].name, drop_first = True)
    df = pd.concat([df, dummie_df], axis=1)

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 1       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 2       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 3       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 4       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 5       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#    sex_Male  smoker_Yes  day_Sat  day_Sun  day_Thur  time_Lunch
# 1         0           0        0        1         0           0
# 2         1           0        0        1         0           0
# 3         1           0        0        1         0           0
# 4         1           0        0        1         0           0
# 5         0           0        0        1         0           0

# %%
#drop the original columns for the ones that were encoded
df = df.drop(columns=encode_cols)
df.head()
# Out:
#    total_bill   tip  size  price_per_person  sex_Male  smoker_Yes  day_Sat  \
# 1       16.99  1.01     2          8.495000         0           0        0
# 2       10.34  1.66     3          3.446667         1           0        0
# 3       21.01  3.50     3          7.003333         1           0        0
# 4       23.68  3.31     2         11.840000         1           0        0
# 5       24.59  3.61     4          6.147500         0           0        0
#
#    day_Sun  day_Thur  time_Lunch
# 1        1         0           0
# 2        1         0           0
# 3        1         0           0
# 4        1         0           0
# 5        1         0           0

# %%
#split the data into train, validate, test
train_val, test = train_test_split(df, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((136, 10), (59, 10), (49, 10))

# %%
#identify the x and y variables 
x_train = train.drop(columns='tip')
y_train = train[['tip']]
x_train.head()
# Out:
#      total_bill  size  price_per_person  sex_Male  smoker_Yes  day_Sat  \
# 19        16.97     3          5.656667         0           0        0
# 173        7.25     2          3.625000         1           1        0
# 119       12.43     2          6.215000         0           0        0
# 29        21.70     2         10.850000         1           0        1
# 238       32.83     2         16.415000         1           1        1
#
#      day_Sun  day_Thur  time_Lunch
# 19         1         0           0
# 173        1         0           0
# 119        0         1           1
# 29         0         0           0
# 238        0         0           0

# %%
#create a min-max scaler object
scaler = MinMaxScaler()
#fit the scaler with the train data
scaler.fit(x_train)
#output the results of the scaler into a new df to use with feature selection
x_train_scaled = scaler.transform(x_train)
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=x_train.columns, index=x_train.index)
x_train_scaled_df.head()
# Out:
#      total_bill  size  price_per_person  sex_Male  smoker_Yes  day_Sat  \
# 19     0.307114   0.4          0.150344       0.0         0.0      0.0
# 173    0.092355   0.2          0.032258       1.0         1.0      0.0
# 119    0.206805   0.2          0.182796       0.0         0.0      0.0
# 29     0.411622   0.2          0.452194       1.0         0.0      1.0
# 238    0.657534   0.2          0.775647       1.0         1.0      1.0
#
#      day_Sun  day_Thur  time_Lunch
# 19       1.0       0.0         0.0
# 173      1.0       0.0         0.0
# 119      0.0       1.0         1.0
# 29       0.0       0.0         0.0
# 238      0.0       0.0         0.0

# %%
#create the kbest object
kbest = SelectKBest(f_regression, k=2)
#fit the kbest object with the train data
kbest.fit(x_train_scaled_df, y_train)
# Out:
# SelectKBest(k=2, score_func=<function f_regression at 0x7fbcce8d18b0>)

# %%
#output the results from the kbest
kbest_results = pd.DataFrame(dict(p=kbest.pvalues_, f=kbest.scores_), index=x_train_scaled_df.columns)
kbest_results
# Out:
#                              p           f
# total_bill        7.186470e-20  115.984909
# size              1.341642e-12   61.259089
# price_per_person  1.310327e-03   10.777792
# sex_Male          2.844794e-01    1.154792
# smoker_Yes        5.579978e-01    0.344909
# day_Sat           9.550468e-01    0.003190
# day_Sun           1.236625e-01    2.400404
# day_Thur          3.013774e-01    1.076380
# time_Lunch        1.821449e-01    1.798647

# %%
x_train_scaled_df.columns[kbest.get_support()]
# Out:
# Index(['total_bill', 'size'], dtype='object')

# %%
#create the model object
model = LinearRegression()
#create the rfe object using the created model
rfe = RFE(model, n_features_to_select=2)
#fit the rfe object
rfe.fit(x_train_scaled_df, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=2)

# %%
#output the results from the rfe
pd.DataFrame({'rfe_ranking': rfe.ranking_}, index=x_train_scaled_df.columns)
# Out:
#                   rfe_ranking
# total_bill                  1
# size                        2
# price_per_person            1
# sex_Male                    3
# smoker_Yes                  7
# day_Sat                     5
# day_Sun                     6
# day_Thur                    4
# time_Lunch                  8

# %%
x_train_scaled_df.columns[rfe.get_support()]
# Out:
# Index(['total_bill', 'price_per_person'], dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Test functions from feature_engineering.py
# - Restart the kernel
#
# - Run the import cell
#
# - Run from top down from here

# %%
#this cell is the data acquisition, cleaning, and prep specific to the 'tips' dataset 
#(same wrangling as above but put in one cell for brevity after restarting the kernel)
df = data('tips')
df['price_per_person'] = df.total_bill / df['size']
encode_cols = [col for col in df.columns if df[col].dtype == 'O']
for col in encode_cols:
    dummie_df = pd.get_dummies(df[col], prefix = df[col].name, drop_first = True)
    df = pd.concat([df, dummie_df], axis=1)
df = df.drop(columns=encode_cols)
train_val, test = train_test_split(df, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
x_train = train.drop(columns='tip')
y_train = train[['tip']]
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=x_train.columns, index=x_train.index)
x_train_scaled_df.head()
# Out:
#      total_bill  size  price_per_person  sex_Male  smoker_Yes  day_Sat  \
# 19     0.307114   0.4          0.150344       0.0         0.0      0.0
# 173    0.092355   0.2          0.032258       1.0         1.0      0.0
# 119    0.206805   0.2          0.182796       0.0         0.0      0.0
# 29     0.411622   0.2          0.452194       1.0         0.0      1.0
# 238    0.657534   0.2          0.775647       1.0         1.0      1.0
#
#      day_Sun  day_Thur  time_Lunch
# 19       1.0       0.0         0.0
# 173      1.0       0.0         0.0
# 119      0.0       1.0         1.0
# 29       0.0       0.0         0.0
# 238      0.0       0.0         0.0

# %% [markdown]
# ##### K Best Function

# %%
#run the select k best function from the feature_engineering.py file call = (x, y, k)
select_k_best(x_train_scaled_df, y_train, 2)
# Out:
# The 2 best features = ['total_bill', 'size']
#                              p           f
# total_bill        7.186470e-20  115.984909
# size              1.341642e-12   61.259089
# price_per_person  1.310327e-03   10.777792
# sex_Male          2.844794e-01    1.154792
# smoker_Yes        5.579978e-01    0.344909
# day_Sat           9.550468e-01    0.003190
# day_Sun           1.236625e-01    2.400404
# day_Thur          3.013774e-01    1.076380
# time_Lunch        1.821449e-01    1.798647

# %% [markdown]
# ##### Recursive Feature Elimination Function

# %%
#run the rfe function from feature_engineering.py - call = (x, y, n_features)
rfe(x_train_scaled_df, y_train, 2)
# Out:
# The 2 best features = ['total_bill', 'price_per_person']
#                   rfe_ranking
# total_bill                  1
# size                        2
# price_per_person            1
# sex_Male                    3
# smoker_Yes                  7
# day_Sat                     5
# day_Sun                     6
# day_Thur                    4
# time_Lunch                  8

# %% [markdown]
# ---

# %% [markdown]
# ### Use the feature engineering functions with the 'swiss' dataset
# - Reset the Kernel
#
# - Run the import cell at the top of the notebook
#
# - Run from top to bottom starting here

# %%
#pull the 'swiss' dataset from pydataset
df = data('swiss')
df.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
#check df data types to make sure all are numeric type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, Courtelary to Rive Gauche
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fertility         47 non-null     float64
#  1   Agriculture       47 non-null     float64
#  2   Examination       47 non-null     int64
#  3   Education         47 non-null     int64
#  4   Catholic          47 non-null     float64
#  5   Infant.Mortality  47 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 2.6+ KB

# %%
#split the data into train, validate, test
train_val, test = train_test_split(df, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((25, 6), (12, 6), (10, 6))

# %%
#assign the 'fertility' column as the y variable and all the other columns as the x variables
x_train = train.drop(columns='Fertility')
y_train = train[['Fertility']]
#view the df
x_train.head()
# Out:
#          Agriculture  Examination  Education  Catholic  Infant.Mortality
# Rolle           60.8           16         10      7.72              16.3
# Lavaux          73.0           19          9      2.84              20.0
# Nyone           50.9           22         12     15.14              16.7
# Conthey         85.9            3          2     99.71              15.1
# Yverdon         49.5           15          8      6.10              22.5

# %% [markdown]
# ##### K Best Function

# %%
#run the select k best function from the feature_engineering.py file call = (x, y, k)
select_k_best(x_train, y_train, 3)
# Out:
# The 3 best features = ['Examination', 'Catholic', 'Infant.Mortality']
#                          p          f
# Agriculture       0.399514   0.736900
# Examination       0.006369   9.008418
# Education         0.191454   1.811436
# Catholic          0.000355  17.518694
# Infant.Mortality  0.024663   5.779868

# %% [markdown]
# ##### Recursive Feature Elimination Function

# %%
#run the rfe function from feature_engineering.py - call = (x, y, n_features)
rfe(x_train, y_train, 3)
# Out:
# The 3 best features = ['Agriculture', 'Examination', 'Infant.Mortality']
#                   rfe_ranking
# Agriculture                 1
# Examination                 1
# Education                   2
# Catholic                    3
# Infant.Mortality            1
